# %% [markdown]
# # Práctica 3: Python
#
# **Resolución de los 20 ejercicios de la Práctica 3 sobre listas, funciones y paquetes, NumPy, diccionarios y pandas, lógica y control de flujo, y bucles.**
#
# ## Requisitos y Entorno
# - **Python 3.12**
# - **Entorno de ejecución:** JupyterLab
# - **Dependencias:** `numpy`, `pandas`, `jupyterlab`

# %% [markdown]
# ## Verificación del Entorno

# %%
import sys
import platform
import numpy as np
import pandas as pd

print("Python :", sys.version)
print("Implementación:", platform.python_implementation())
print("NumPy :", np.__version__)
print("pandas :", pd.__version__)

assert sys.version_info[:2] == (3, 12), "Esta práctica requiere Python 3.12"
print("\nEntorno verificado correctamente.")
# Out:
# Python : 3.12.11 (main, Aug 18 2025, 19:17:54) [MSC v.1944 64 bit (AMD64)]
# Implementación: CPython
# NumPy : 2.5.3
# pandas : 3.0.6
#
# Entorno verificado correctamente.

# %% [markdown]
# ## Ejercicio 1 — Catálogo de productos como lista

# %%
catalogo = [
    "Auriculares BT", 59.90,
    "Smartwatch S2", 149.00,
    "Tablet 10", 219.00,
    "Cargador USB-C", 18.50,
    "Cafetera Expres", 189.00,
    "Robot Aspirador", 279.00,
]

print("Total de elementos:", len(catalogo))
print("Total de productos:", len(catalogo) // 2)

nombres = catalogo[0::2]
precios = catalogo[1::2]

pos_robot = catalogo.index("Robot Aspirador")
precio_robot = catalogo[pos_robot + 1]
print("Precio Robot Aspirador:", precio_robot)

ultimos_tres_nombres = nombres[-3:]
print("Tres últimos nombres:", ultimos_tres_nombres)

precio_medio = round(sum(precios) / len(precios), 2)
print("Precio medio:", precio_medio)
# Out:
# Total de elementos: 12
# Total de productos: 6
# Precio Robot Aspirador: 279.0
# Tres últimos nombres: ['Cargador USB-C', 'Cafetera Expres', 'Robot Aspirador']
# Precio medio: 152.4

# %% [markdown]
# ## Ejercicio 2 — Inventario multialmacén con listas anidadas

# %%
inventario = [
    ["ALM-NORTE", "Robot Aspirador", 34, 201.50],
    ["ALM-NORTE", "Monitor 27", 58, 142.00],
    ["ALM-SUR", "Silla Ergonomica", 12, 178.90],
    ["ALM-SUR", "Robot Aspirador", 7, 201.50],
    ["ALM-ESTE", "Cafetera Expres", 41, 131.20],
    ["ALM-ESTE", "Monitor 27", 25, 142.00],
]

print("Nombre producto de la 4ta fila:", inventario[3][1])

valor_stock = []
for fila in inventario:
    valor = round(fila[2] * fila[3], 2)
    valor_stock.append([fila[1], valor])

print("Valor stock:", valor_stock)

valor_inmovilizado = sum([f[1] for f in valor_stock])
print("Valor inmovilizado total:", round(valor_inmovilizado, 2))

inventario_sur = inventario[2:4]
valor_sur = round(sum([f[2] * f[3] for f in inventario_sur]), 2)
print("Valor inmovilizado ALM-SUR:", valor_sur)
# Out:
# Nombre producto de la 4ta fila: Robot Aspirador
# Valor stock: [['Robot Aspirador', 6851.0], ['Monitor 27', 8236.0], ['Silla Ergonomica', 2146.8], ['Robot Aspirador', 1410.5], ['Cafetera Expres', 5379.2], ['Monitor 27', 3550.0]]
# Valor inmovilizado total: 27573.5
# Valor inmovilizado ALM-SUR: 3557.3

# %% [markdown]
# Problema al usar posiciones fijas:
# Si los datos de los almacenes no están ordenados o seguidos, sacar la información contando las posiciones fallará y sacará datos de otros lados. Lo más seguro en estos casos es usar una condición (un if) en vez de posiciones fijas.

# %% [markdown]
# ## Ejercicio 3 — Manipulación destructiva y copias de listas

# %%
precios_originales = [59.90, 149.00, 219.00, 18.50, 189.00, 279.00]

precios_rebajados = precios_originales
precios_rebajados[0] = 49.90
print("Originales:", precios_originales)
print("Rebajados:", precios_rebajados)
print("Explicación: Al usar '=', Python no copia los datos reales, sino que crea un enlace a la misma lista original en la memoria.")

precios_originales[0] = 59.90

copia_list = list(precios_originales)
copia_slice = precios_originales[:]
copia_list[0] = 99.90
print("Originales tras tocar copia:", precios_originales)

for i in range(len(copia_slice)):
    copia_slice[i] = round(copia_slice[i] * 0.9, 2)
print("Copia rebajada 10%:", copia_slice)

copia_slice.extend([10.00, 20.00])
copia_slice.insert(2, 100.00)

del copia_slice[4]
descartado = copia_slice.pop()
print("Descartado:", descartado)

print("ID original:", id(precios_originales))
print("ID copia_list:", id(copia_list))
print("ID copia_slice:", id(copia_slice))
# Out:
# Originales: [49.9, 149.0, 219.0, 18.5, 189.0, 279.0]
# Rebajados: [49.9, 149.0, 219.0, 18.5, 189.0, 279.0]
# Explicación: Al usar '=', Python no copia los datos reales, sino que crea un enlace a la misma lista original en la memoria.
# Originales tras tocar copia: [59.9, 149.0, 219.0, 18.5, 189.0, 279.0]
# Copia rebajada 10%: [53.91, 134.1, 197.1, 16.65, 170.1, 251.1]
# Descartado: 20.0
# ID original: 1616427470016
# ID copia_list: 1616427482496
# ID copia_slice: 1616427468864

# %% [markdown]
# ## Ejercicio 4 — Cola de pedidos pendientes

# %%
cola = ["PED-10021", "PED-10007", "PED-10044", "PED-10012", "PED-10033", "PED-10008"]

cola_invertida = cola[::-1]

cola_ordenada = sorted(cola)
print("Ordenada externamente:", cola_ordenada)
print("Original intacta:", cola)

cola.sort(reverse=True)
print("Ordenada en sitio:", cola)

atendidos = [cola.pop(0), cola.pop(0)]
print("Atendidos:", atendidos)

cola.insert(0, "PED-99999")
print("Cola final:", cola)

pct = round(len(atendidos) / (len(atendidos) + len(cola)) * 100, 1)
print(f"Atendidos: {len(atendidos)} | Pendientes: {len(cola)} | Avance: {pct}%")
# Out:
# Ordenada externamente: ['PED-10007', 'PED-10008', 'PED-10012', 'PED-10021', 'PED-10033', 'PED-10044']
# Original intacta: ['PED-10021', 'PED-10007', 'PED-10044', 'PED-10012', 'PED-10033', 'PED-10008']
# Ordenada en sitio: ['PED-10044', 'PED-10033', 'PED-10021', 'PED-10012', 'PED-10008', 'PED-10007']
# Atendidos: ['PED-10044', 'PED-10033']
# Cola final: ['PED-99999', 'PED-10021', 'PED-10012', 'PED-10008', 'PED-10007']
# Atendidos: 2 | Pendientes: 5 | Avance: 28.6%

# %% [markdown]
# ## Ejercicio 5 — Funciones propias para el cálculo de importes

# %%
def calcular_importe(unidades, precio_unitario, descuento_pct=0):
    """Devuelve el importe neto redondeado a dos decimales."""
    return round((unidades * precio_unitario) * (1 - descuento_pct / 100), 2)

def resumen_pedido(unidades, precio_unitario, descuento_pct=0):
    """Devuelve una tupla: (importe_bruto, ahorro, importe_neto)."""
    bruto = unidades * precio_unitario
    neto = calcular_importe(unidades, precio_unitario, descuento_pct)
    ahorro = bruto - neto
    return round(bruto, 2), round(ahorro, 2), neto

bruto, ahorro, neto = resumen_pedido(unidades=3, precio_unitario=59.90, descuento_pct=10)
print(f"Bruto: {bruto}, Ahorro: {ahorro}, Neto: {neto}")

help(calcular_importe)

pedidos = [
    (3, 59.90, 10),
    (1, 279.00, 0),
    (5, 18.50, 20),
    (2, 149.00, 5),
    (4, 89.90, 15),
]

importes = [calcular_importe(*p) for p in pedidos]
print("Max:", max(importes))
print("Min:", min(importes))
print("Sorted:", sorted(importes))
print("Len:", len(importes))
# Out:
# Bruto: 179.7, Ahorro: 17.97, Neto: 161.73
# Help on function calcular_importe in module __main__:
#
# calcular_importe(unidades, precio_unitario, descuento_pct=0)
#     Devuelve el importe neto redondeado a dos decimales.
#
# Max: 305.66
# Min: 74.0
# Sorted: [74.0, 161.73, 279.0, 283.1, 305.66]
# Len: 5

# %% [markdown]
# ## Ejercicio 6 — Normalización de códigos SKU con métodos

# %%
skus_crudos = [
    " elc-0012-es ", "HOG-0045-ES", "dep-0003-pt ",
    "ofi-0021-es", " ELC-0012-ES", "hog-0099-fr ",
]

skus_limpios = [s.strip().upper() for s in skus_crudos]

print("Apariciones de ELC-0012-ES:", skus_limpios.count("ELC-0012-ES"))
print("Posición de OFI-0021-ES:", skus_limpios.index("OFI-0021-ES"))

partes = [s.split("-") for s in skus_limpios]
print("SKU en partes:", partes)

skus_es = [s.replace("-", ".") for s in skus_limpios if s.endswith("-ES")]
print("SKUs ES modificados:", skus_es)

cadena_unica = " | ".join(skus_limpios)
print("Cadena única:", cadena_unica)
# Out:
# Apariciones de ELC-0012-ES: 2
# Posición de OFI-0021-ES: 3
# SKU en partes: [['ELC', '0012', 'ES'], ['HOG', '0045', 'ES'], ['DEP', '0003', 'PT'], ['OFI', '0021', 'ES'], ['ELC', '0012', 'ES'], ['HOG', '0099', 'FR']]
# SKUs ES modificados: ['ELC.0012.ES', 'HOG.0045.ES', 'OFI.0021.ES', 'ELC.0012.ES']
# Cadena única: ELC-0012-ES | HOG-0045-ES | DEP-0003-PT | OFI-0021-ES | ELC-0012-ES | HOG-0099-FR

# %% [markdown]
# ## Ejercicio 7 — Paquetes, importaciones y módulo propio

# %%
import math
print("Raíz cuadrada 2809:", math.sqrt(2809))

from math import pi, ceil
print("Palés completos:", ceil(1375 / 24))

import numpy as np
import pandas as pd
print("NumPy version:", np.__version__)
print("pandas version:", pd.__version__)

import random
random.seed(42)
valoraciones = [random.randint(1, 5) for _ in range(10)]
print("Valoraciones:", valoraciones)
# Fijamos la semilla para que los números aleatorios sean siempre los mismos y se pueda replicar el resultado.

import sys
sys.path.append("../src")
from utilidades import calcular_importe as util_calc_importe, clasificar_ticket
print("Importe de la utilidad:", util_calc_importe(4, 89.90, 15))
print("Clasificación del ticket:", clasificar_ticket(305.66))
# Out:
# Raíz cuadrada 2809: 53.0
# Palés completos: 58
# NumPy version: 2.5.3
# pandas version: 3.0.6
# Valoraciones: [1, 1, 3, 2, 2, 2, 1, 5, 1, 5]
# Importe de la utilidad: 305.66
# Clasificación del ticket: Medio

# %% [markdown]
# ## Ejercicio 8 — Del cálculo con listas al cálculo vectorizado

# %%
unidades = [3, 1, 5, 2, 4, 6, 2, 8, 3, 1]
precios = [59.90, 279.00, 18.50, 149.00, 89.90, 27.50, 219.00, 14.90, 64.00, 239.00]

# Multiplicar dos listas normales en Python da error porque el operador * sirve para repetir elementos, no para multiplicar uno a uno.

np_unidades = np.array(unidades)
np_precios = np.array(precios)
print("Dtype unidades:", np_unidades.dtype, "| Shape:", np_unidades.shape)
print("Dtype precios:", np_precios.dtype, "| Shape:", np_precios.shape)

importes_np = np_unidades * np_precios
print("Suma total importes:", importes_np.sum())

importes_np_recargo = importes_np * 1.04

mixto = np.array([1, "dos", 3.0, True])
print("Dtype mixto:", mixto.dtype)
# Numpy convierte todos los elementos a texto (string) porque en sus arrays todos los datos tienen que ser del mismo tipo obligatoriamente.
# Out:
# Dtype unidades: int64 | Shape: (10,)
# Dtype precios: float64 | Shape: (10,)
# Suma total importes: 2362.0
# Dtype mixto: <U32

# %%
# %%timeit
[u * p for u, p in zip(unidades, precios)]
# Out:
# 732 ns ± 2.54 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
np_unidades * np_precios
# Out:
# 797 ns ± 2.14 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Ejercicio 9 — Subsetting con máscaras booleanas

# %%
caros = np_precios > 100
print("Máscara caros:", caros)

print("Precios que superan 100:", np_precios[caros])

print("Cantidad de caros:", caros.sum())
# Sumar booleanos funciona porque internamente True se evalúa como 1 y False como 0.

importes_caros = importes_np[caros]
print("Suma importes caros:", importes_caros.sum())

print("Posiciones que cumplen la condición:", np.where(caros))

varias = np_unidades >= 2
seleccion = (np_precios > 100) & (np_unidades >= 2)
print("Importes (precio>100 y unidades>=2):", importes_np[seleccion])
# Out:
# Máscara caros: [False  True False  True False False  True False False  True]
# Precios que superan 100: [279. 149. 219. 239.]
# Cantidad de caros: 4
# Suma importes caros: 1254.0
# Posiciones que cumplen la condición: (array([1, 3, 6, 9]),)
# Importes (precio>100 y unidades>=2): [298. 438.]

# %% [markdown]
# ## Ejercicio 10 — Matriz de ventas por trimestre y región

# %%
import numpy as np

ventas_2d = np.array([
    [15200.50, 11800.25, 12950.00, 9870.40, 13400.10],
    [16840.75, 12310.60, 13480.90, 11020.35, 14100.80],
    [12535.72, 10663.06, 11221.59, 12673.08, 12334.38],
])

print("Shape:", ventas_2d.shape, "Ndim:", ventas_2d.ndim, "Size:", ventas_2d.size)
# Shape 3x5 indica trimestres y regiones. Ndim=2 es el número de dimensiones. Size=15 son las celdas totales.

print("Fila T2:", ventas_2d[1, :])
print("Columna Centro:", ventas_2d[:, 4])

print("Valor T3, Este:", ventas_2d[2, 2])

print("Submatriz T1-T2, primeras 3 regiones:\n", ventas_2d[:2, :3])

totales_trimestre = ventas_2d.sum(axis=1)
totales_region = ventas_2d.sum(axis=0)
print("Totales trimestre:", totales_trimestre)
print("Totales región:", totales_region)

fila_t4 = ventas_2d[2, :] * 1.06
ventas_ampliada = np.vstack([ventas_2d, fila_t4])
print("Shape ampliado:", ventas_ampliada.shape)

etiquetas_regiones = ["Norte", "Sur", "Este", "Oeste", "Centro"]
idx_max = np.argmax(totales_region)
print("Región con mayor facturación:", etiquetas_regiones[idx_max])
# Out:
# Shape: (3, 5) Ndim: 2 Size: 15
# Fila T2: [16840.75 12310.6  13480.9  11020.35 14100.8 ]
# Columna Centro: [13400.1  14100.8  12334.38]
# Valor T3, Este: 11221.59
# Submatriz T1-T2, primeras 3 regiones:
#  [[15200.5  11800.25 12950.  ]
#  [16840.75 12310.6  13480.9 ]]
# Totales trimestre: [63221.25 67753.4  59427.83]
# Totales región: [44576.97 34773.91 37652.49 33563.83 39835.28]
# Shape ampliado: (4, 5)
# Región con mayor facturación: Norte

# %% [markdown]
# ## Ejercicio 11 — Estadística descriptiva sobre telemetría simulada

# %%
rng = np.random.default_rng(2024)
temperatura = rng.normal(68, 6.5, 500)
vibracion = np.abs(rng.normal(2.4, 0.8, 500))

media_t = temperatura.mean()
mediana_t = np.median(temperatura)
print(f"Temperatura -> Media: {media_t:.2f}, Mediana: {mediana_t:.2f}, Std: {temperatura.std():.2f}, Min: {temperatura.min():.2f}, Max: {temperatura.max():.2f}")
# Como la media y la mediana son valores muy parecidos, podemos decir que los datos tienen una distribución bastante simétrica.

percentiles = np.percentile(vibracion, [25, 50, 75, 95])
print("Percentiles vibración [25,50,75,95]:", percentiles)

matriz_tele = np.column_stack([temperatura, vibracion])
print("Shape matriz:", matriz_tele.shape)

corr = np.corrcoef(temperatura, vibracion)
print("Correlación:\n", corr)
# El valor de correlación es casi 0, lo que significa que no parece haber relación directa entre la temperatura y la vibración.

umbral = media_t + 2 * temperatura.std()
superan = (temperatura > umbral).sum()
print(f"Superan umbral: {superan} lecturas ({superan/500*100:.1f}%)")
# Se utiliza una semilla para asegurar que los datos generados sean idénticos cada vez que se ejecute la celda.
# Out:
# Temperatura -> Media: 68.03, Mediana: 68.13, Std: 6.50, Min: 49.01, Max: 88.29
# Percentiles vibración [25,50,75,95]: [1.89488326 2.39381414 2.92451892 3.72951895]
# Shape matriz: (500, 2)
# Correlación:
#  [[1.         0.00673339]
#  [0.00673339 1.        ]]
# Superan umbral: 11 lecturas (2.2%)

# %% [markdown]
# ## Ejercicio 12 — Diccionarios simples y anidados

# %%
tarifas_envio = {"Norte": 4.95, "Sur": 5.50, "Este": 5.20, "Oeste": 6.10, "Centro": 3.90}

print("Tarifa Este:", tarifas_envio["Este"])

tarifas_envio["Insular"] = 9.80
tarifas_envio["Oeste"] = 5.95

del tarifas_envio["Sur"]
print("¿Está Sur?:", "Sur" in tarifas_envio)

for reg, tar in tarifas_envio.items():
    print(f"{reg} -> {tar} €")

red_logistica = {
    "Norte": {"almacen": "ALM-NORTE", "tarifa": 4.95, "entrega_h": 24},
    "Este": {"almacen": "ALM-ESTE", "tarifa": 5.20, "entrega_h": 48},
    "Centro": {"almacen": "ALM-CENTRO","tarifa": 3.90, "entrega_h": 24},
}

print("Entrega almacén Este:", red_logistica["Este"]["entrega_h"])

red_logistica["Oeste"] = {"almacen": "ALM-OESTE", "tarifa": 5.95, "entrega_h": 72}
for r, d in red_logistica.items():
    print(f"Región {r}: Almacén {d['almacen']}, Tarifa {d['tarifa']}, Entrega {d['entrega_h']}h")
# Out:
# Tarifa Este: 5.2
# ¿Está Sur?: False
# Norte -> 4.95 €
# Este -> 5.2 €
# Oeste -> 5.95 €
# Centro -> 3.9 €
# Insular -> 9.8 €
# Entrega almacén Este: 48
# Región Norte: Almacén ALM-NORTE, Tarifa 4.95, Entrega 24h
# Región Este: Almacén ALM-ESTE, Tarifa 5.2, Entrega 48h
# Región Centro: Almacén ALM-CENTRO, Tarifa 3.9, Entrega 24h
# Región Oeste: Almacén ALM-OESTE, Tarifa 5.95, Entrega 72h

# %% [markdown]
# Un diccionario conviene cuando buscamos datos por una etiqueta identificativa, obteniendo un acceso mucho más rápido y semántico que dependiendo del orden (índice) en una lista.

# %% [markdown]
# ## Ejercicio 13 — De diccionario a DataFrame y lectura de CSV

# %%
import pandas as pd

almacenes = {
    "codigo": ["ALM-NORTE", "ALM-SUR", "ALM-ESTE", "ALM-OESTE", "ALM-CENTRO"],
    "ciudad": ["Bilbao", "Sevilla", "Valencia", "Vigo", "Madrid"],
    "m2": [4200, 3100, 3800, 2600, 6500],
    "operarios": [48, 31, 39, 22, 74],
}

df_almacenes = pd.DataFrame(almacenes)
print(df_almacenes)

df_almacenes = df_almacenes.set_index("codigo")
print(df_almacenes)

ventas = pd.read_csv("../data/ventas_retail.csv")
empleados = pd.read_csv("../data/empleados.csv", index_col="id_empleado")
sensores = pd.read_csv("../data/sensores_planta.csv")

print("Ventas head:\n", ventas.head(8))
print("Ventas tail:\n", ventas.tail(3))
print("Shape:", ventas.shape)

ventas.info()

print("Nulos por columna:\n", ventas.isna().sum())
# Los nulos se concentran fuertemente en 'canal' y 'satisfaccion'.

print("Shapes finales:", ventas.shape, empleados.shape, sensores.shape)
# Out:
#        codigo    ciudad    m2  operarios
# 0   ALM-NORTE    Bilbao  4200         48
# 1     ALM-SUR   Sevilla  3100         31
# 2    ALM-ESTE  Valencia  3800         39
# 3   ALM-OESTE      Vigo  2600         22
# 4  ALM-CENTRO    Madrid  6500         74
#               ciudad    m2  operarios
# codigo
# ALM-NORTE     Bilbao  4200         48
# ALM-SUR      Sevilla  3100         31
# ALM-ESTE    Valencia  3800         39
# ALM-OESTE       Vigo  2600         22
# ALM-CENTRO    Madrid  6500         74
# Ventas head:
#     id_pedido       fecha  region    categoria          producto  unidades  \
# 0  PED-10153  2025-01-01  Centro  Electronica        Tablet 10"         2
# 1  PED-10030  2025-01-02     Sur      Deporte   Zapatilla Trail         4
# 2  PED-10343  2025-01-02   Oeste      Oficina  Teclado Mecanico         3
# 3  PED-10298  2025-01-02   Oeste        Hogar   Robot Aspirador         6
# 4  PED-10144  2025-01-03     Sur      Deporte       Mochila 30L         5
# ...

# %% [markdown]
# ## Ejercicio 14 — Selección con corchetes, loc e iloc

# %%
s_serie = empleados["salario_base"]
s_df = empleados[["salario_base"]]
print(type(s_serie), type(s_df))

subset = empleados[["departamento", "ciudad", "salario_base"]]

filas_slicing = empleados[9:15] # pos 10 a 15 incl (indices numéricos desde el 0)

fila_1042 = empleados.loc["EMP-1042"]

dept_mod = empleados.loc[["EMP-1005", "EMP-1020", "EMP-1099"], ["departamento", "modalidad"]]

primeras = empleados.iloc[:3, [2, 5]]

nombres_bonus = empleados.loc[:, ["nombre", "bonus_pct"]]
# Out:
# <class 'pandas.Series'> <class 'pandas.DataFrame'>

# %% [markdown]
# | Método | Trabaja por | Uso principal |
# | --- | --- | --- |
# | `[]` | Etiquetas (cols) y pos (slicing) | Extraer columnas completas o rangos simples |
# | `.loc` | Etiquetas del índice/cols | Extraer filas y/o columnas con nombres concretos |
# | `.iloc` | Posición entera | Extraer basándonos en coordenadas numéricas |

# %% [markdown]
# ## Ejercicio 15 — Columnas calculadas, agregación y exportación

# %%
ventas["importe_bruto"] = ventas["unidades"] * ventas["precio_unitario"]
ventas["importe_neto"] = (ventas["importe_bruto"] * (1 - ventas["descuento_pct"] / 100)).round(2)
ventas["ticket_medio"] = ventas["importe_neto"] / ventas["unidades"]

ag_region = ventas.groupby("region")["importe_neto"].sum().sort_values(ascending=False)
print("Facturación por región:\n", ag_region)

ag_cat_canal = ventas.groupby(["categoria", "canal"]).agg({"importe_neto": "mean", "unidades": "sum"})

top_5_prod = ventas.groupby("producto")["importe_neto"].sum().nlargest(5)

ventas["satisfaccion"] = ventas["satisfaccion"].fillna(ventas["satisfaccion"].median())
ventas["canal"] = ventas["canal"].fillna("Desconocido")

ag_region.to_csv("../outputs/facturacion_por_region.csv")
# Out:
# Facturación por región:
#  region
# Norte     44576.98
# Centro    39835.28
# Este      37652.49
# Sur       34773.90
# Oeste     33563.82
# Name: importe_neto, dtype: float64
